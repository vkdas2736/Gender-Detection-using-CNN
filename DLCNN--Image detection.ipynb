# %%
import os
import cv2

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
img_path="C:/Users/VAMSI KRISHNA DAS/OneDrive/Desktop/face_images"

# %%
img_path
# Out:
# 'C:/Users/VAMSI KRISHNA DAS/OneDrive/Desktop/face_images'

# %%
img_path+"/female/"
# Out:
# 'C:/Users/VAMSI KRISHNA DAS/OneDrive/Desktop/face_images/female/'

# %%
img_names_female=os.listdir(img_path+"/female/")

# %%
img_names_female
# Out:
# ['131422.jpg.jpg',
#  '131423.jpg.jpg',
#  '131425.jpg.jpg',
#  '131427.jpg.jpg',
#  '131428.jpg.jpg',
#  '131429.jpg.jpg',
#  '131432.jpg.jpg',
#  '131433.jpg.jpg',
#  '131435.jpg.jpg',
#  '131437.jpg.jpg',
#  '131440.jpg.jpg',
#  '131449.jpg.jpg',
#  '131452.jpg.jpg',
#  '131458.jpg.jpg',
#  '131459.jpg.jpg',
#  '131468.jpg.jpg',
#  '131469.jpg.jpg',
#  '131472.jpg.jpg',
#  '131475.jpg.jpg',
#  '131482.jpg.jpg',
#  '131484.jpg.jpg',
#  '131485.jpg.jpg',
#  '131486.jpg.jpg',
#  '131489.jpg.jpg',
#  '131490.jpg.jpg',
#  '131506.jpg.jpg',
#  '131507.jpg.jpg',
#  '131508.jpg.jpg',
#  '131509.jpg.jpg',
#  '131511.jpg.jpg',
#  '131513.jpg.jpg',
#  '131515.jpg.jpg',
#  '131516.jpg.jpg',
#  '131517.jpg.jpg',
#  '131521.jpg.jpg',
#  '131523.jpg.jpg',
#  '131527.jpg.jpg',
#  '131529.jpg.jpg',
#  '131530.jpg.jpg',
#  '131531.jpg.jpg',
#  '131537.jpg.jpg',
#  '131541.jpg.jpg',
#  '131544.jpg.jpg',
#  '131546.jpg.jpg',
#  '131547.jpg.jpg',
#  '131551.jpg.jpg',
#  '131552.jpg.jpg',
# ...

# %%
len(img_names_female)
# Out:
# 1000

# %%
type(img_names_female)
# Out:
# list

# %%
img_names_female[0]
# Out:
# '131422.jpg.jpg'

# %%
img_path+"/female/"+img_names_female[0]
# Out:
# 'C:/Users/VAMSI KRISHNA DAS/OneDrive/Desktop/face_images/female/131422.jpg.jpg'

# %%
pic = cv2.imread(img_path+"/female/"+img_names_female[0])

# %%
pic
# Out:
# array([[[37, 39, 39],
#         [42, 44, 44],
#         [43, 45, 45],
#         ...,
#         [55, 53, 53],
#         [58, 56, 56],
#         [45, 43, 43]],
#
#        [[32, 34, 34],
#         [32, 34, 34],
#         [28, 30, 30],
#         ...,
#         [58, 56, 56],
#         [53, 51, 51],
#         [67, 65, 65]],
#
#        [[27, 29, 29],
#         [32, 34, 34],
#         [28, 30, 30],
#         ...,
#         [64, 62, 62],
#         [59, 57, 57],
#         [67, 65, 65]],
#
#        ...,
#
#        [[18, 27, 17],
#         [11, 20, 10],
#         [ 9, 16,  9],
#         ...,
#         [15, 15, 15],
#         [22, 23, 21],
#         [25, 26, 24]],
#
#        [[13, 24, 16],
#         [ 6, 17,  9],
#         [ 7, 14,  9],
#         ...,
#         [21, 19, 19],
#         [18, 16, 16],
#         [14, 12, 12]],
#
#        [[13, 24, 16],
#         [ 6, 17,  9],
#         [ 7, 14,  9],
#         ...,
#         [22, 20, 20],
#         [20, 18, 18],
#         [17, 15, 15]]], dtype=uint8)

# %%
plt.imshow(pic)

# %%
img_datasets=[]

# %%
img_lables=[]

# %%
from tensorflow.keras.preprocessing.image import img_to_array

# %%
for name in img_names_female:
    f_image=cv2.imread(img_path+"/female/"+name)
    f_image=cv2.resize(f_image,(96,96))
    f_image=img_to_array(f_image)
    img_datasets.append(f_image)
    img_lables.append(0)

# %%
len(img_datasets)

# %%
len(img_lables)
# Out:
# 1000

# %%
img_path
# Out:
# 'C:/Users/VAMSI KRISHNA DAS/OneDrive/Desktop/face_images'

# %%
img_path+"/male/"
# Out:
# 'C:/Users/VAMSI KRISHNA DAS/OneDrive/Desktop/face_images/male/'

# %%
img_names_male=os.listdir(img_path+"/male/")

# %%
img_names_male
# Out:
# ['090544.jpg.jpg',
#  '090545.jpg.jpg',
#  '090548.jpg.jpg',
#  '090550.jpg.jpg',
#  '090553.jpg.jpg',
#  '090557.jpg.jpg',
#  '090558.jpg.jpg',
#  '090559.jpg.jpg',
#  '090563.jpg.jpg',
#  '090567.jpg.jpg',
#  '090570.jpg.jpg',
#  '090571.jpg.jpg',
#  '090574.jpg.jpg',
#  '090575.jpg.jpg',
#  '090579.jpg.jpg',
#  '090581.jpg.jpg',
#  '090584.jpg.jpg',
#  '090586.jpg.jpg',
#  '090590.jpg.jpg',
#  '090594.jpg.jpg',
#  '090597.jpg.jpg',
#  '090603.jpg.jpg',
#  '090608.jpg.jpg',
#  '090610.jpg.jpg',
#  '090612.jpg.jpg',
#  '090614.jpg.jpg',
#  '090631.jpg.jpg',
#  '090634.jpg.jpg',
#  '090639.jpg.jpg',
#  '090646.jpg.jpg',
#  '090648.jpg.jpg',
#  '090652.jpg.jpg',
#  '090662.jpg.jpg',
#  '090663.jpg.jpg',
#  '090665.jpg.jpg',
#  '090668.jpg.jpg',
#  '090671.jpg.jpg',
#  '090674.jpg.jpg',
#  '090678.jpg.jpg',
#  '090682.jpg.jpg',
#  '090690.jpg.jpg',
#  '090694.jpg.jpg',
#  '090699.jpg.jpg',
#  '090700.jpg.jpg',
#  '090706.jpg.jpg',
#  '090708.jpg.jpg',
#  '090718.jpg.jpg',
# ...

# %%
img_path+"/male/"+img_names_male[0]
# Out:
# 'C:/Users/VAMSI KRISHNA DAS/OneDrive/Desktop/face_images/male/090544.jpg.jpg'

# %%
pic1=cv2.imread(img_path+"/male/"+img_names_male[0])

# %%
pic1
# Out:
# array([[[  4,   7,  28],
#         [  3,   7,  26],
#         [  2,   6,  25],
#         ...,
#         [ 14,  33,  54],
#         [ 18,  37,  58],
#         [ 11,  29,  52]],
#
#        [[  4,   7,  28],
#         [  3,   7,  26],
#         [  2,   6,  24],
#         ...,
#         [ 16,  34,  57],
#         [ 16,  34,  57],
#         [ 14,  32,  55]],
#
#        [[  5,   6,  26],
#         [  5,   6,  26],
#         [  3,   5,  23],
#         ...,
#         [  7,  27,  52],
#         [ 13,  33,  58],
#         [ 23,  40,  66]],
#
#        ...,
#
#        [[135, 128, 185],
#         [124, 118, 177],
#         [122, 114, 177],
#         ...,
#         [  1,   0,   2],
#         [  1,   0,   2],
#         [  0,   0,   0]],
#
#        [[133, 126, 183],
#         [126, 120, 179],
#         [126, 118, 181],
#         ...,
#         [  0,   0,   1],
#         [  1,   0,   2],
#         [  0,   0,   0]],
#
#        [[132, 126, 181],
#         [128, 122, 179],
#         [130, 123, 184],
# ...

# %%
plt.imshow(pic1)

# %%
for name in img_names_male:
    m_image=cv2.imread(img_path+"/male/"+name)
    m_image=cv2.resize(m_image,(96,96))
    m_image=img_to_array(m_image)
    img_datasets.append(m_image)
    img_lables.append(1)

# %%
len(img_datasets)
# Out:
# 2000

# %%
len(img_lables)
# Out:
# 2000

# %%
pd.DataFrame(img_lables)
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 1995  1
# 1996  1
# 1997  1
# 1998  1
# 1999  1
#
# [2000 rows x 1 columns]

# %%
pd.DataFrame(img_lables)[0].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
img_datasets_array=np.array(img_datasets,dtype="float")

# %%
img_lables_array=np.array(img_lables)

# %%
type(img_datasets_array)
# Out:
# numpy.ndarray

# %%
type(img_lables_array)
# Out:
# numpy.ndarray

# %%
img_datasets_scale=img_datasets_array/255.0

# %%
img_datasets_scale.max()
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(img_datasets_scale,img_lables_array,test_size=0.25)

# %%
Xtrain.shape,Xtest.shape,img_datasets_scale.shape
# Out:
# ((1500, 96, 96, 3), (500, 96, 96, 3), (2000, 96, 96, 3))

# %%
ytrain.shape,ytest.shape
# Out:
# ((1500,), (500,))

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dropout,BatchNormalization,Dense,Flatten

# %%
cnn_smodel=Sequential()

cnn_smodel

cnn_smodel.add( Conv2D(32, (3,3), activation  = "relu", padding = "valid", strides = (1,1), 
                       input_shape = (96,96,3)))

# %%
cnn_smodel.add(MaxPooling2D((2,2),strides=2,padding="valid"))

# %%
cnn_smodel.add(BatchNormalization(axis=-1))

# %%
cnn_smodel.add( Conv2D(32, (3,3), activation  = "relu", padding = "valid", strides = (1,1), 
                       ))

cnn_smodel.add(MaxPooling2D((2,2),strides=2,padding="valid"))

cnn_smodel.add(BatchNormalization(axis=-1))

# %%
cnn_smodel.add( Conv2D(32, (3,3), activation  = "relu", padding = "valid", strides = (1,1), 
                       ))

cnn_smodel.add(MaxPooling2D((2,2),strides=2,padding="valid"))

cnn_smodel.add(BatchNormalization(axis=-1))

# %%
cnn_smodel.add( Conv2D(32, (3,3), activation  = "relu", padding = "valid", strides = (1,1), 
                       ))

cnn_smodel.add(MaxPooling2D((2,2),strides=2,padding="valid"))

cnn_smodel.add(BatchNormalization(axis=-1))

# %%
cnn_smodel.add(Flatten())

# %%
cnn_smodel.add(Dense(64,activation="relu"))

# %%
cnn_smodel.add(Dense(32,activation="relu"))

# %%
cnn_smodel.add(Dense(16,activation="relu"))

# %%
cnn_smodel.add(Dense(8,activation="relu"))

# %%
cnn_smodel.add(Dense(16,activation="relu"))

# %%
cnn_smodel.add(Dense(32,activation="relu"))

# %%
cnn_smodel.add(Dense(64,activation="relu"))

# %%
cnn_smodel.add(Dense(2,activation="softmax"))

# %%
cnn_smodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 94, 94, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 92, 92, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 45, 45, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 45, 45, 32)       128
#  ormalization)
#
#  conv2d_3 (Conv2D)           (None, 43, 43, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 21, 32)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 21, 21, 32)       128
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 19, 19, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 9, 32)         0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 9, 9, 32)         128
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 32)          9248
#
# ...

# %%
cnn_smodel.compile(optimizer="adam",
                   loss="sparse_categorical_crossentropy"
                 ,
                   metrics=["accuracy"]



)

# %%
cnn_smodel.fit(Xtrain,ytrain,epochs=15)
# Out:
# Epoch 1/15
# 47/47 [==============================] - 57s 1s/step - loss: 0.6675 - accuracy: 0.5620
# Epoch 2/15
# 47/47 [==============================] - 47s 1s/step - loss: 0.4799 - accuracy: 0.7787
# Epoch 3/15
# 47/47 [==============================] - 49s 1s/step - loss: 0.3693 - accuracy: 0.8427
# Epoch 4/15
# 47/47 [==============================] - 49s 1s/step - loss: 0.2731 - accuracy: 0.8900
# Epoch 5/15
# 47/47 [==============================] - 49s 1s/step - loss: 0.1731 - accuracy: 0.9320
# Epoch 6/15
# 47/47 [==============================] - 47s 1s/step - loss: 0.1780 - accuracy: 0.9353
# Epoch 7/15
# 47/47 [==============================] - 48s 1s/step - loss: 0.1321 - accuracy: 0.9480
# Epoch 8/15
# 47/47 [==============================] - 52s 1s/step - loss: 0.1125 - accuracy: 0.9553
# Epoch 9/15
# 47/47 [==============================] - 47s 1s/step - loss: 0.0743 - accuracy: 0.9727
# Epoch 10/15
# ...

# %%
cnn_smodel.evaluate(Xtest,ytest)
# Out:
# 16/16 [==============================] - 8s 452ms/step - loss: 0.4416 - accuracy: 0.9100
# [0.44155359268188477, 0.9100000262260437]

# %%
Xtest.shape
# Out:
# (500, 96, 96, 3)

# %%
Xtest[450]
# Out:
# array([[[0.33333333, 0.29803922, 0.28235294],
#         [0.32941176, 0.29411765, 0.27843137],
#         [0.3254902 , 0.29019608, 0.2745098 ],
#         ...,
#         [0.25098039, 0.38431373, 0.50588235],
#         [0.24313725, 0.36862745, 0.49019608],
#         [0.24313725, 0.36862745, 0.48235294]],
#
#        [[0.32941176, 0.29411765, 0.27843137],
#         [0.32941176, 0.29411765, 0.27843137],
#         [0.3254902 , 0.29019608, 0.2745098 ],
#         ...,
#         [0.2745098 , 0.40392157, 0.5372549 ],
#         [0.27058824, 0.39215686, 0.51764706],
#         [0.26666667, 0.39215686, 0.50980392]],
#
#        [[0.32941176, 0.29411765, 0.27843137],
#         [0.32941176, 0.29411765, 0.27843137],
#         [0.3254902 , 0.29411765, 0.2745098 ],
#         ...,
#         [0.2745098 , 0.40784314, 0.54117647],
#         [0.2745098 , 0.39607843, 0.53333333],
#         [0.2745098 , 0.39607843, 0.52156863]],
#
#        ...,
#
#        [[0.34901961, 0.31764706, 0.30588235],
# ...

# %%
ytest[450]
# Out:
# 1

# %%
plt.imshow(Xtest[450])

# %%
Xtest[280]
# Out:
# array([[[0.10196078, 0.10980392, 0.11372549],
#         [0.09411765, 0.10196078, 0.10196078],
#         [0.09019608, 0.09803922, 0.09803922],
#         ...,
#         [0.03921569, 0.03529412, 0.05490196],
#         [0.03529412, 0.03529412, 0.05882353],
#         [0.03529412, 0.03529412, 0.05882353]],
#
#        [[0.09803922, 0.10588235, 0.10980392],
#         [0.08627451, 0.09411765, 0.09411765],
#         [0.0745098 , 0.08235294, 0.07843137],
#         ...,
#         [0.04705882, 0.04705882, 0.07058824],
#         [0.03921569, 0.03921569, 0.0627451 ],
#         [0.03137255, 0.03137255, 0.05490196]],
#
#        [[0.10588235, 0.10588235, 0.10588235],
#         [0.09803922, 0.09803922, 0.09803922],
#         [0.08235294, 0.08235294, 0.07843137],
#         ...,
#         [0.04705882, 0.04705882, 0.07058824],
#         [0.04313725, 0.04313725, 0.06666667],
#         [0.03137255, 0.03137255, 0.05490196]],
#
#        ...,
#
#        [[0.0745098 , 0.07058824, 0.10980392],
# ...

# %%
ytest[280]
# Out:
# 0

# %%
plt.imshow(Xtest[280])
